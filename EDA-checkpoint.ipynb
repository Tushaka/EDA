# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def load_dataset(file_path):
    return pd.read_csv(file_path)


df = load_dataset("/Users/Lenovo/.ipynb_checkpoints/Auto Sales data.csv")
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
sns.countplot(data=df, x='STATUS')
df['QUANTITYORDERED'].value_counts()
# Out:
# QUANTITYORDERED
# 34    111
# 21    101
# 46     99
# 27     98
# 45     96
# 41     95
# 31     95
# 26     94
# 29     92
# 32     90
# 20     90
# 25     90
# 22     89
# 48     89
# 24     88
# 38     88
# 33     88
# 44     88
# 49     88
# 36     87
# 37     83
# 43     81
# 28     79
# 39     79
# 40     77
# 30     74
# 42     74
# 23     71
# 47     70
# 35     67
# 50     63
# 55     16
# 66      5
# 15      4
# 51      4
# 61      3
# 18      3
# 60      3
# 76      3
# 59      3
# 56      3
# 19      3
# 64      3
# 10      2
# 6       2
# 11      2
# 54      2
# 70      2
# 97      1
# 85      1
# 62      1
# 52      1
# 16      1
# 13      1
# 58      1
# 65      1
# 12      1
# 77      1
# Name: count, dtype: int64

# %%
df['PRODUCTLINE'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['SALES'])
# Out:
# (array([449., 940., 695., 358., 186.,  76.,  28.,   8.,   6.,   1.]),
#  array([  482.13 ,  1842.197,  3202.264,  4562.331,  5922.398,  7282.465,
#          8642.532, 10002.599, 11362.666, 12722.733, 14082.8  ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(df['SALES'])
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(df['SALES'])
# Out:
# <Axes: >

# %%
sns.lineplot(x='STATUS',y='PRODUCTLINE',data=df)
# Out:
# <Axes: xlabel='STATUS', ylabel='PRODUCTLINE'>

# %%
sns.heatmap(pd.crosstab(df['SALES'],df['QUANTITYORDERED']))
# Out:
# <Axes: xlabel='QUANTITYORDERED', ylabel='SALES'>

# %%
sns.pairplot(data=df,hue='SALES')
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098952         6.491081
# std       91.877521         9.762135    42.042549         4.230544
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
#
#               SALES  DAYS_SINCE_LASTORDER         MSRP
# count   2747.000000           2747.000000  2747.000000
# mean    3553.047583           1757.085912   100.691664
# std     1838.953901            819.280576    40.114802
# min      482.130000             42.000000    33.000000
# 25%     2204.350000           1077.000000    68.000000
# ...

# %%
sns.scatterplot(x='STATUS', y='SALES',hue='QUANTITYORDERED',data=df)
# Out:
# <Axes: xlabel='STATUS', ylabel='SALES'>
